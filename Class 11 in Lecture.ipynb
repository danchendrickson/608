# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
y=1
t=0
endTime = 2.0
PlotSmoothingFactor = 10.0
lam = 0.1

# %%
h=0.01

totalErrors=[]

for q in range(6):
    h = 10.0**(-1-float(q))
    Steps = int(endTime / h)
    print(h)
    errors = []
    for i in range(Steps):
        t = i / Steps * endTime
        yexct=math.exp(lam*t)
        err = abs(yexct-y)
        errors.append(err)
        y=y+h*(lam*y)
    #print(sum(errors))
    totalErrors.append(sum(errors))
# Out:
# 0.1
# 0.01
# 0.001
# 0.0001
# 1e-05
# 1e-06

# %%
plt.figure()
p0=plt.plot(range(6),totalErrors)
plt.dpi=1200
plt.figure(figsize=(18, 16)) 
plt.show()
